# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from main import *

sns.set_theme(style="darkgrid")

# %% [markdown]
# # Plot showing the correlation between the price and the score of items that cost less than $10

# %%
df = pd.read_csv("../datasets/cleanData/workingDataset.csv")

sns.stripplot(data=df_pltens, x='rScore', y='pPrice', jitter=True, alpha=0.3)

plt.show()
